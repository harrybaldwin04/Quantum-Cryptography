# %% [markdown]
# # B92 Quantum Key Distribution Simulation
#
# ## Overview
# This notebook implements a simulation of the B92 quantum key distribution protocol.

# %%
import numpy as np
from numpy import random
import matplotlib.pyplot as plt
from scipy.stats import norm, binom
import time

print("B92 Simulation Loaded!")
